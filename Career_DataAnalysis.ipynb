# %% [markdown]
# <a href="https://colab.research.google.com/github/yagyanshsharma/Career-data-analysis/blob/main/Career_DataAnalysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Employee Career Survey Analysis**![linear-flat-visitor-analytics-website-hero-image-illustration-seo-smm-online-marketing-concept-laptop-tablet-with-report-data-screen_126523-2649.avif](data:image/avif;base64,...)

# %%
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.graph_objects as go
import plotly.io as pio
pio.renderers.default = "png"

# %%
Data = pd.read_csv("Career Survey Data Analysis.csv")

# %%
Data
# Out:
#     Your Current Country.  Your Current Zip Code / Pin Code Your Gender  \
# 0                   India                            273005        Male
# 1                   India                            851129        Male
# 2                   India                            123106      Female
# 3                   India                            834003        Male
# 4                   India                            301019      Female
# ..                    ...                               ...         ...
# 230                 India                            605008        Male
# 231                 India                            722207        Male
# 232                 India                            604102      Female
# 233                 India                            122002        Male
# 234                 India                            605102      Female
#
#     Which of the below factors influence the most about your career aspirations ?  \
# ...

# %%
#first of all we will inspect the columns of the dataset
Data.columns
# Out:
# Index(['Your Current Country.', 'Your Current Zip Code / Pin Code',
#        'Your Gender',
#        'Which of the below factors influence the most about your career aspirations ?',
#        'Would you definitely pursue a Higher Education / Post Graduation outside of India ? If only you have to self sponsor it.',
#        'How likely is that you will work for one employer for 3 years or more ?',
#        'Would you work for a company whose mission is not clearly defined and publicly posted.',
#        'How likely would you work for a company whose mission is misaligned with their public actions or even their product ?',
#        'How likely would you work for a company whose mission is not bringing social impact ?',
#        'What is the most preferred working environment for you.',
#        'Which of the below Employers would you work with.',
#        'Which type of learning environment that you are most likely to work in ?',
# ...

# %%
Country = Data["Your Current Country."].value_counts()
label = Country.index
counts = Country.values
colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue']
fig = go.Figure(data=[go.Pie(labels = label, values = counts)])
fig.update_layout(title_text = 'Country')
fig.update_traces(hoverinfo = 'label+value', textinfo = 'percent', textfont_size = 30,
                  marker = dict(colors = colors, line = dict(color = 'black', width = 2)))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
Country
# Out:
# Your Current Country.
# India                       231
# Germany                       2
# United Arab Emirates          1
# United States of America      1
# Name: count, dtype: int64

# %% [markdown]
# # **Factors that influencing Career Aspirations**

# %%
Data.head()
# Out:
#   Your Current Country.  Your Current Zip Code / Pin Code Your Gender  \
# 0                 India                            273005        Male
# 1                 India                            851129        Male
# 2                 India                            123106      Female
# 3                 India                            834003        Male
# 4                 India                            301019      Female
#
#   Which of the below factors influence the most about your career aspirations ?  \
# 0       People who have changed the world for better
# 1       People who have changed the world for better
# 2                         Social Media like LinkedIn
# 3      People from my circle, but not family members
# 4             Influencers who had successful careers
#
#   Would you definitely pursue a Higher Education / Post Graduation outside of India ? If only you have to self sponsor it.  \
# 0                       Yes, I will earn and do that
# ...

# %%
Question1 = Data["Which of the below factors influence the most about your career aspirations ?"].value_counts()
label = Question1.index
counts = Question1.values
# Expand colors to accommodate more categories
colors = px.colors.qualitative.Plotly # Using a Plotly qualitative color sequence for more colors
fig = go.Figure(data = [go.Pie(labels = label, values = counts, marker=dict(colors=colors))])
fig.update_layout(title_text = ("Factors Influencing Career Aspirations"))
fig.update_traces(hoverinfo = "label+value", textinfo = "percent", textfont_size = 12,
                  marker = dict(line = dict(color = "black", width = 2)))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#Now we will analyse and visualise who wants to go abroad for higher education or post graduation,
#and what reasons they'll go or will not go.
Q2 = "Would you definitely pursue a Higher Education / Post Graduation outside of India ? If only you have to self sponsor it."
Q2 = Data[Q2].value_counts()

# %%
Q2
# Out:
# Would you definitely pursue a Higher Education / Post Graduation outside of India ? If only you have to self sponsor it.
# Yes, I will earn and do that                                    110
# No I would not be pursuing Higher Education outside of India     65
# No, But if someone could bare the cost I will                    60
# Name: count, dtype: int64

# %%
label = Q2.index
counts = Q2.values
colors = ['lightgreen','skyblue']
fig = go.Figure(data =[go.Pie(labels = label, values= counts , marker = dict(colors = colors))])
fig.update_layout(title_text = "Would you definitely pursue a Higher Education / Post Graduation outside of India ? If only you have to self sponsor it.")
fig.update_traces(hoverinfo = "label+value", textinfo = "percent", textfont_size= 12,
                     marker = dict(line =dict(color = 'black', width = 3)))
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#now we will analyse and visualise how many people wantb to work on company for 3 years, more than 3 years,
#or less than 3 years
Q3 = "How likely is that you will work for one employer for 3 years or more ?"
Q3 = Data[Q3].value_counts()
Q3
# Out:
# How likely is that you will work for one employer for 3 years or more ?
# This will be hard to do, but if it is the right company I would try    139
# Will work for 3 years or more                                           79
# No way, 3 years with one employer is crazy                              17
# Name: count, dtype: int64

# %%
label = Q3.index
counts = Q3.values
colors = ['aqua', 'green']
fig = go.Figure(data =[go.Pie(labels = label, values= counts, marker = dict(colors = colors))])
fig.update_layout(title_text = "How likely is that you will work for one employer for 3 years or more ?")
fig.update_traces(hoverinfo = "label+value", textinfo = "percent", textfont_size = 13,
                  marker = dict(line = dict(color = "black", width = 3)))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#now we will analyse and visualise which working enviroment genz prefers to work in
#column 10
Q4 = Data["What is the most preferred working environment for you."].value_counts()
label = Q4.index
counts = Q4.values
colors = ['green','blue','yellow']
fig = go.Figure(data = [go.Pie(labels = label, values=counts, marker = dict(colors = colors))])
fig.update_layout(title_text = "What is the most preferred working environment for you.")
fig.update_traces(hoverinfo ='label+value', textinfo = 'percent', textfont_size= 13,
                  marker = (dict (line = dict(color = 'black', width = 3))))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
Q5 = Data['Which of the below careers looks close to your Aspirational job ?'].value_counts()
labels = Q5.index
counts = Q5.values
colors = ['orange', 'gray','lightblue']
fig = go.Figure(data =[go.Pie(labels = label, values = counts, marker = dict(colors = colors))])
fig.update_layout(title_text = "Which of the below careers looks close to your Aspirational job ?")
fig.update_traces(hoverinfo ="label+value", textinfo = 'percent', textfont_size = 13,
                  marker = dict(line = dict(color = 'black', width = 3)))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# In this project i analyzed and visualized data from an employers career survey.I explored which countries most of the respondents come from whether they are interested in studying or working abroad and whether they are likely to stay in a company for at least 3 years. I also looked at the key factors that influence genzs career choices their preferred job roles and how closely different career options match their aspirational jobs.

# %% [markdown]
# # **Key Insights**

# %% [markdown]
# **-** We observed that around 98% of the survey participants are from india.
#
# **-** Data shows that approximately 33% of genz's career aspirations are shaped by parental influence.
#
# **-** We also observed that around 46-47% of people want to pursue higher education  or post-graduation abroad and earn there.
#
# **-** while 59% of genz's find 3-year tenure difficult, they would stay longer for the righ company.
#
# **-** Genz,s preference is highest at 26% for remote work' and lowest at 4% for fully remote with zero office access.
#
# **-** Genz prefference peaks at 21% for remote work with travel options, while its lowest at 14% of hybrid setups requiring less than 10 days or a 3 days a month in the office.

# %% [markdown]
# **Thank you!**
#
# This project was done as part of my data analysis practice.
